# %% [markdown]
# <a href="https://colab.research.google.com/github/juanivazquez/SdT/blob/main/Practicas_Levendis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GEC0319

# %%
# https://github.com/juanivazquez/SdT.git
! git clone https://github.com/jlevendi/Time-Series-Econometrics.git
# Out:
# Cloning into 'Time-Series-Econometrics'...
# remote: Enumerating objects: 102, done.
# remote: Total 102 (delta 0), reused 0 (delta 0), pack-reused 102
# Receiving objects: 100% (102/102), 6.49 MiB | 15.42 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages('fpp3')
# install.packages('car')
# install.packages('haven')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘numDeriv’, ‘warp’, ‘BH’, ‘Rcpp’, ‘distributional’, ‘progressr’, ‘slider’, ‘anytime’, ‘fable’, ‘fabletools’, ‘feasts’, ‘tsibble’, ‘tsibbledata’, ‘urca’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/numDeriv_2016.8-1.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 76053 bytes (74 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# %%R
# library(fpp3)
# library(car)
# library(haven)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: ── Attaching packages ──────────────────────────────────────────── fpp3 0.4.0 ──
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: ✔ tibble      3.1.7     ✔ tsibble     1.1.2
# ✔ dplyr       1.0.9     ✔ tsibbledata 0.4.1
# ✔ tidyr       1.2.0     ✔ feasts      0.3.0
# ✔ lubridate   1.8.0     ✔ fable       0.3.2
# ✔ ggplot2     3.3.6
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: ── Conflicts ───────────────────────────────────────────────── fpp3_conflicts ──
# ✖ lubridate::date()    masks base::date()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ tsibble::intersect() masks base::intersect()
# ✖ tsibble::interval()  masks lubridate::interval()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ tsibble::setdiff()   masks base::setdiff()
# ✖ tsibble::union()     masks base::union()
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: carData
#
# ...

# %%
  # %%R
 data <- read_dta('/content/Time-Series-Econometrics/book data for distribution/stata_data/AR1nonzero.dta') # 
 head(data)
# Out:
# # A tibble: 6 × 3
#    time   error     X
#   <dbl>   <dbl> <dbl>
# 1  1001 -0.425   19.8
# 2  1002 -1.38    18.5
# 3  1003 -1.07    18.2
# 4  1004  1.61    20.7
# 5  1005  1.00    21.4
# 6  1006  0.0500  20.7
